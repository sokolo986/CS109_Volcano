# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cleanup
import stats
#import tidal_forces
import pickle

# %matplotlib inline

# %%
eruptions = pd.io.excel.read_excel('Eruptions.xlsx', header = 1)
volcanoes = pd.io.excel.read_excel('Volcanoes.xlsx', header = 1)
#eruptions.head()

# %%
#volcanoes.head()

# %%
eruptions.columns
# Out:
# Index([u'Volcano Number', u'Volcano Name', u'Eruption Number', u'Eruption Category', u'Area of Activity', u'VEI', u'VEI Modifier', u'Start Year Modifier', u'Start Year', u'Start Year Uncertainty', u'Start Month', u'Start Day Modifier', u'Start Day', u'Start Day Uncertainty', u'Evidence Method (dating)', u'End Year Modifier', u'End Year', u'End Year Uncertainty', u'End Month', u'End Day Modifier', u'End Day', u'End Day Uncertainty'], dtype='object')

# %%
volcanoes.columns
# Out:
# Index([u'Volcano Number', u'Volcano Name', u'Country', u'Primary Volcano Type', u'Activity Evidence', u'Last Known Eruption', u'Region', u'Subregion', u'Latitude', u'Longitude', u'Elevation (m)', u'Dominant Rock Type', u'Tectonic Setting'], dtype='object')

# %% [markdown]
# ### Only explore confirmed eruptions

# %%
conf_erup = eruptions[eruptions['Eruption Category'] == 'Confirmed Eruption']
print 'Amount of Confirmed Eruptions:', conf_erup.shape[0]
# Out:
# Amount of Confirmed Eruptions: 9536

# %%
#conf_erup.head()

# %% [markdown]
# ### Only explore eruptions with no uncertainty in the start day

# %%
print conf_erup['Start Day'].unique()
print conf_erup['Start Month'].unique()
## Notice that there are some zeroes and nans
# Out:
# [ 27.  17.   6.  30.  29.  13.   3.   4.  22.  21.  31.  24.  26.   9.   8.
#    7.  28.  20.  18.  23.  12.  15.  25.  11.   2.   5.  16.  19.   1.  10.
#   14.   0.  nan]
# [  9.   8.   7.   6.   5.   4.   3.   2.   1.  12.  11.  10.   0.  nan]

# %%
conf_erup = conf_erup[(conf_erup['Start Month'] != 0) & (conf_erup['Start Day'] != 0)]
conf_erup = cleanup.eliminate_nan(conf_erup, 'Start Day')
conf_erup = cleanup.eliminate_nan(conf_erup, 'Start Month')

# %%
print conf_erup['Start Day'].unique()
print conf_erup['Start Month'].unique()
# Out:
# [ 27.  17.   6.  30.  29.  13.   3.   4.  22.  21.  31.  24.  26.   9.   8.
#    7.  28.  20.  18.  23.  12.  15.  25.  11.   2.   5.  16.  19.   1.  10.
#   14.]
# [  9.   8.   7.   6.   5.   4.   3.   2.   1.  12.  11.  10.]

# %%
## Check uncertainty in dates

print conf_erup['Start Day Uncertainty'].unique()
print conf_erup['Start Year Uncertainty'].unique()
print 'Number of Confirmed Eruptions with Start Days and Months:', conf_erup.shape[0]
# Out:
# [  nan    2.    4.    3.    7.    5.    1.   12.   20.  150.  180.   30.
#    90.   15.    9.  365.   45.    8.  270.   75.   60.  120.   10.    6.
#   730.]
# [ nan  10.  13.]
# Number of Confirmed Eruptions with Start Days and Months: 3950

# %%
# Only accept nan's in uncertainty
conf_erup = conf_erup[conf_erup['Start Day Uncertainty'].isnull()]
conf_erup = conf_erup[conf_erup['Start Year Uncertainty'].isnull()]

print 'Number of Confirmed Eruptions with No Uncertain Start Dates:', conf_erup.shape[0]
# Out:
# Number of Confirmed Eruptions with No Uncertain Start Dates: 3624

# %%
print 'Number of Volcanoes In Confirmed Eruptions Dataset:', conf_erup['Volcano Number'].unique().shape[0]
# Out:
# Number of Volcanoes In Confirmed Eruptions Dataset: 457

# %% [markdown]
# # Volcano and Eruption Features

# %%
year_min = conf_erup['Start Year'].min()
year_max = conf_erup['Start Year'].max()
print 'Start Date Range:', year_max - year_min, 'years'
# Out:
# Start Date Range: 1968 years

# %%
conf_erup['Start Year'].hist(figsize = (15,6), bins = 100, log=True)
plt.xlim([0,2100])
plt.show()

#Values are highly skewed to more recent dates...as expected

# %%
#Convert dates --- 2 days are on 2/29, one of those days is not actually a leap year---raises error---changed date from 2/29 to 2/28
from datetime import datetime
conf_erup['Start Day'][6724] = 28
conf_erup['Start Date'] = cleanup.convert_dates(conf_erup, 'Start Year', 'Start Month', 'Start Day')

# %%
conf_erup['Julian Start Dates'] = cleanup.julian_date(conf_erup, 'Start Date')
conf_erup['End Date'] = cleanup.convert_dates(conf_erup, 'End Year', 'End Month', 'End Day')

# %%
# VEI
print conf_erup['VEI'].unique()
print 'Number of NaN VEI values:', conf_erup[conf_erup['VEI'].isnull()].shape[0]
# only 68 out of 3624 eruptions --- will impute values
# Out:
# [  3.   1.   2.  nan   0.   4.   5.   6.]
# Number of NaN VEI values: 68

# %%
#VEI is skewed slightly to lower values with most values at 2
conf_erup['VEI'].hist(bins = 6)
plt.show()

# %%
conf_erup['Impute VEI'] = cleanup.impute_vei(conf_erup,'VEI')

# %%
conf_erup['Impute VEI'][0:10]
# Out:
# 0     3
# 1     1
# 3     2
# 4     2
# 5     2
# 6     0
# 7     1
# 8     2
# 9     1
# 10    1
# Name: Impute VEI, dtype: float64

# %%
# merge eruptions and volcanos
conf_erup = pd.merge(conf_erup, volcanoes, on = ['Volcano Number'], how = 'left')

# %%
# #create tide dictionary with numpy array of tides as values and eruptions as keys
# tides_dict1 = tidal_forces.iter_tides(conf_erup[0:200], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides.txt', 'w') as handle:
#     pickle.dump(tides_dict1, handle)

# tides_dict2 = tidal_forces.iter_tides(conf_erup[200:400], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides2.txt', 'w') as handle:
#     pickle.dump(tides_dict2, handle)
# tides_dict3 = tidal_forces.iter_tides(conf_erup[400:600], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides3.txt', 'w') as handle:
#     pickle.dump(tides_dict3, handle)
# tides_dict4 = tidal_forces.iter_tides(conf_erup[600:800], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides4.txt', 'w') as handle:
#     pickle.dump(tides_dict4, handle)
# tides_dict5 = tidal_forces.iter_tides(conf_erup[800:1000], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides5.txt', 'w') as handle:
#     pickle.dump(tides_dict5, handle)
# tides_dict6 = tidal_forces.iter_tides(conf_erup[1000:1200], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides6.txt', 'w') as handle:
#     pickle.dump(tides_dict6, handle)
# tides_dict7 = tidal_forces.iter_tides(conf_erup[1200:1400], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides7.txt', 'w') as handle:
#     pickle.dump(tides_dict7, handle)
# tides_dict8 = tidal_forces.iter_tides(conf_erup[1400:1600], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides8.txt', 'w') as handle:
#     pickle.dump(tides_dict8, handle)
# tides_dict9 = tidal_forces.iter_tides(conf_erup[1600:1800], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides9.txt', 'w') as handle:
#     pickle.dump(tides_dict9, handle)
# tides_dict10 = tidal_forces.iter_tides(conf_erup[1800:2000], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides10.txt', 'w') as handle:
#     pickle.dump(tides_dict10, handle)
# tides_dict11 = tidal_forces.iter_tides(conf_erup[2000:2200], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides11.txt', 'w') as handle:
#     pickle.dump(tides_dict11, handle)
# tides_dict12 = tidal_forces.iter_tides(conf_erup[2200:2400], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides12.txt', 'w') as handle:
#     pickle.dump(tides_dict12, handle)
# tides_dict13 = tidal_forces.iter_tides(conf_erup[2400:2600], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides13.txt', 'w') as handle:
#     pickle.dump(tides_dict13, handle)
# tides_dict14 = tidal_forces.iter_tides(conf_erup[2600:2800], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides14.txt', 'w') as handle:
#     pickle.dump(tides_dict14, handle)
# tides_dict15 = tidal_forces.iter_tides(conf_erup[2800:3000], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides15.txt', 'w') as handle:
#     pickle.dump(tides_dict15, handle)
# tides_dict16 = tidal_forces.iter_tides(conf_erup[3000:3200], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides16.txt', 'w') as handle:
#     pickle.dump(tides_dict16, handle)
# tides_dict17 = tidal_forces.iter_tides(conf_erup[3200:3400], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides17.txt', 'w') as handle:
#     pickle.dump(tides_dict17, handle)
# tides_dict18 = tidal_forces.iter_tides(conf_erup[3400:], 'Julian Start Dates', 'Latitude', 'Longitude', 'Eruption Number')
# with open('tides18.txt', 'w') as handle:
#     pickle.dump(tides_dict18, handle)

# %%
tides = pickle.load(open('Tides/Tides/tides.txt', 'r'))
tides2 = pickle.load(open('Tides/Tides/tides2.txt', 'r'))
tides3 = pickle.load(open('Tides/Tides/tides3.txt', 'r'))
tides4 = pickle.load(open('Tides/Tides/tides4.txt', 'r'))
tides5 = pickle.load(open('Tides/Tides/tides5.txt', 'r'))
tides6 = pickle.load(open('Tides/Tides/tides6.txt', 'r'))
tides7 = pickle.load(open('Tides/Tides/tides7.txt', 'r'))
tides8 = pickle.load(open('Tides/Tides/tides8.txt', 'r'))
tides9 = pickle.load(open('Tides/Tides/tides9.txt', 'r'))
tides10 = pickle.load(open('Tides/Tides/tides10.txt', 'r'))
tides11 = pickle.load(open('Tides/Tides/tides11.txt', 'r'))
tides12 = pickle.load(open('Tides/Tides/tides12.txt', 'r'))
tides13 = pickle.load(open('Tides/Tides/tides13.txt', 'r'))
tides14 = pickle.load(open('Tides/Tides/tides14.txt', 'r'))
tides15 = pickle.load(open('Tides/Tides/tides15.txt', 'r'))
tides16 = pickle.load(open('Tides/Tides/tides16.txt', 'r'))
tides17 = pickle.load(open('Tides/Tides/tides17.txt', 'r'))
tides18 = pickle.load(open('Tides/Tides/tides18.txt', 'r'))

# %%
merged_tides = {k:v for d in (tides,tides2,tides3,tides4,tides5,tides6,tides7,tides8,tides9,tides10,tides11,tides12,tides13,tides14,tides15,tides16,tides17,tides18) for k, v in d.iteritems()}

# %%
#Dictionaries of tidal phases
mf_dict = tidal_forces.mfPhasesDict(merged_tides)
mm_dict = tidal_forces.mmPhasesDict(merged_tides)
ssa_dict = tidal_forces.ssaPhasesDict(merged_tides)
diurnal_dict = tidal_forces.diurnalPhasesDict(merged_tides)
semi_dict = tidal_forces.semiPhasesDict(merged_tides)

# %%
mf = pd.Series(mf_dict, name = 'Mf Phases')
mm = pd.Series(mm_dict, name = 'Mm phases')
ssa = pd.Series(ssa_dict, name = 'Ssa Phases')
diurnal = pd.Series(diurnal_dict, name = 'Diurnal Phases')
semi = pd.Series(semi_dict, name = 'SemiDiurnal Phases')
phases_df = pd.concat([mf,mm,ssa,diurnal,semi], axis=1).reset_index()
phases_df.rename(columns={'index':'Eruption Number'}, inplace = True)
phases_df.shape
conf_erup.shape
# Out:
# (3624, 38)

# %%
conf_erup = pd.merge(conf_erup, phases_df, on = ['Eruption Number'], how = 'left')

# %%
conf_erup.head()
with open('conf_erup.txt', 'w') as handle:
    pickle.dump(conf_erup, handle)

# %%
pickle.load(open('conf_erup.txt', 'r'))
# Out:
#       Volcano Number          Volcano Name_x  Eruption Number  \
# 0             283040               Ontakesan            20964
# 1             283040               Ontakesan            20963
# 2             283040               Ontakesan            17457
# 3             345020      Rincon de la Vieja            20961
# 4             345020      Rincon de la Vieja            20813
# 5             345020      Rincon de la Vieja            11106
# 6             345020      Rincon de la Vieja            11105
# 7             345020      Rincon de la Vieja            11104
# 8             345020      Rincon de la Vieja            11103
# 9             345020      Rincon de la Vieja            11102
# 10            345020      Rincon de la Vieja            11100
# 11            345020      Rincon de la Vieja            11099
# 12            345020      Rincon de la Vieja            11098
# 13            345020      Rincon de la Vieja            11078
# 14            345020      Rincon de la Vieja            11097
# 15            345020      Rincon de la Vieja            11096
# 16            345020      Rincon de la Vieja            11095
# 17            345020      Rincon de la Vieja            11093
# 18            251020                   Manam            20956
# 19            251020                   Manam            14935
# 20            251020                   Manam            14934
# 21            251020                   Manam            14932
# 22            251020                   Manam            14931
# 23            251020                   Manam            14930
# 24            251020                   Manam            14929
# 25            251020                   Manam            14928
# 26            251020                   Manam            14927
# 27            251020                   Manam            14925
# 28            251020                   Manam            14919
# 29            251020                   Manam            14908
# ...              ...                     ...              ...
# 3594          283030                 Fujisan            17452
# 3595          283030                 Fujisan            17445
# 3596          283030                 Fujisan            17444
# 3597          283030                 Fujisan            17439
# 3598          283030                 Fujisan            17438
# 3599          283030                 Fujisan            17436
# 3600          283030                 Fujisan            17433
# 3601          305060            Changbaishan            19648
# 3602          283050                 Hakusan            17483
# 3603          283050                 Hakusan            17476
# 3604          382081   Picos Volcanic System            13007
# 3605          213020             Nemrut Dagi            13527
# 3606          221141                Dama Ali            13947
# 3607          382100                  Furnas            13042
# 3608          284050             Hachijojima            18300
# 3609          284050             Hachijojima            18299
# 3610          284050             Hachijojima            18297
# 3611          382090             Agua de Pau            13033
# 3612          382090             Agua de Pau            13032
# 3613          283131            Hiuchigatake            17847
# 3614          211010           Campi Flegrei            10041
# 3615          211030                  Ischia            13393
# 3616          231070           Rahat, Harrat            14154
# 3617          283271                  Towada            18099
# 3618          284020                 Niijima            18249
# 3619          282070  Ibusuki Volcanic Field            17030
# 3620          282070  Ibusuki Volcanic Field            17028
# 3621          282130            Yufu-Tsurumi            17368
# 3622          284030               Kozushima            17576
# 3623          283200                  Naruko            17994
#
#        Eruption Category                        Area of Activity  VEI  \
# 0     Confirmed Eruption                           Summit crater    3
# 1     Confirmed Eruption                          1979 Crater #7    0
# 2     Confirmed Eruption                   200 m SW of Kengamine    2
# 15             ...              10.830   -85.324           1916
# 16             ...              10.830   -85.324           1916
# 17             ...              10.830   -85.324           1916
# 18             ...              -4.080   145.037           1807
# 19             ...              -4.080   145.037           1807
# 20             ...              -4.080   145.037           1807
# 21             ...              -4.080   145.037           1807
# 22             ...              -4.080   145.037           1807
# 23             ...              -4.080   145.037           1807
# 24             ...              -4.080   145.037           1807
# 25             ...              -4.080   145.037           1807
# 26             ...              -4.080   145.037           1807
# 27             ...              -4.080   145.037           1807
# 28             ...              -4.080   145.037           1807
# 29             ...              -4.080   145.037           1807
# ...            ...                 ...       ...            ...
# 3594           ...              35.361   138.728           3776
# 3595           ...              35.361   138.728           3776
# 3596           ...              35.361   138.728           3776
# 3597           ...              35.361   138.728           3776
# 3598           ...              35.361   138.728           3776
# 3599           ...              35.361   138.728           3776
# 3600           ...              35.361   138.728           3776
# 3601           ...              41.980   128.080           2744
# 3602           ...              36.155   136.771           2702
# 3603           ...              36.155   136.771           2702
# 3604           ...              37.780   -25.670            350
# 3605           ...              38.650    42.230           2948
# 3606           ...              11.280    41.630           1068
# 3607           ...              37.770   -25.320            805
# 3608           ...              33.137   139.766            854
# 3609           ...              33.137   139.766            854
# 3610           ...              33.137   139.766            854
# 3611           ...              37.770   -25.470            947
# 3612           ...              37.770   -25.470            947
# 3613           ...              36.955   139.285           2356
# 3614           ...              40.827    14.139            458
# 3615           ...              40.730    13.897            789
# 3616           ...              23.080    39.780           1744
# 3617           ...              40.510   140.880           1011
# 3618           ...              34.397   139.270            432
# 3619           ...              31.220   130.570            924
# 3620           ...              31.220   130.570            924
# 3621           ...              33.282   131.390           1584
# 3622           ...              34.219   139.153            572
# 3623           ...              38.729   140.734            470
#
#                     Dominant Rock Type  \
# 0         Andesite / Basaltic Andesite
# 1         Andesite / Basaltic Andesite
# 2         Andesite / Basaltic Andesite
# 3         Andesite / Basaltic Andesite
# 4         Andesite / Basaltic Andesite
# 5         Andesite / Basaltic Andesite
# 6         Andesite / Basaltic Andesite
# 7         Andesite / Basaltic Andesite
# 8         Andesite / Basaltic Andesite
# 9         Andesite / Basaltic Andesite
# 10        Andesite / Basaltic Andesite
# 11        Andesite / Basaltic Andesite
# 12        Andesite / Basaltic Andesite
# 13        Andesite / Basaltic Andesite
# 14        Andesite / Basaltic Andesite
# 15        Andesite / Basaltic Andesite
# 16        Andesite / Basaltic Andesite
# 17        Andesite / Basaltic Andesite
# 18               Basalt / Picro-Basalt
# 19               Basalt / Picro-Basalt
# 20               Basalt / Picro-Basalt
# 21               Basalt / Picro-Basalt
# 22               Basalt / Picro-Basalt
# 23               Basalt / Picro-Basalt
# 24               Basalt / Picro-Basalt
# 25               Basalt / Picro-Basalt
# 26               Basalt / Picro-Basalt
# 27               Basalt / Picro-Basalt
# 28               Basalt / Picro-Basalt
# 29               Basalt / Picro-Basalt
# ...                                ...
# 3594             Basalt / Picro-Basalt
# 3595             Basalt / Picro-Basalt
# 3596             Basalt / Picro-Basalt
# 3597             Basalt / Picro-Basalt
# 3598             Basalt / Picro-Basalt
# 3599             Basalt / Picro-Basalt
# 3600             Basalt / Picro-Basalt
# 3601         Trachyte / Trachyandesite
# 3602      Andesite / Basaltic Andesite
# 3603      Andesite / Basaltic Andesite
# 3604  Trachybasalt / Tephrite Basanite
# 3605                          Rhyolite
# 3606             Basalt / Picro-Basalt
# 3607         Trachyte / Trachyandesite
# 3608             Basalt / Picro-Basalt
# 3609             Basalt / Picro-Basalt
# 3610             Basalt / Picro-Basalt
# 3611         Trachyte / Trachyandesite
# 3612         Trachyte / Trachyandesite
# 3613      Andesite / Basaltic Andesite
# 3614         Trachyte / Trachyandesite
# 3615         Trachyte / Trachyandesite
# 3616             Basalt / Picro-Basalt
# 3617      Andesite / Basaltic Andesite
# 3618                          Rhyolite
# 3619      Andesite / Basaltic Andesite
# 3620      Andesite / Basaltic Andesite
# 3621      Andesite / Basaltic Andesite
# 3622                          Rhyolite
# 3623                          Rhyolite
#
#                                   Tectonic Setting   Mf Phases   Mm phases  \
# 0     Subduction zone / Continental crust (>25 km)   80.907760  226.110292
# 1     Subduction zone / Continental crust (>25 km)  368.696925  217.097255
# 2     Subduction zone / Continental crust (>25 km)  317.569546  157.402032
# 3     Subduction zone / Continental crust (>25 km)  194.231332  259.550086
# 4     Subduction zone / Continental crust (>25 km)   95.666179  245.312060
# 5     Subduction zone / Continental crust (>25 km)  353.147877  175.036284
# 6     Subduction zone / Continental crust (>25 km)  348.404100  172.685051
# 7     Subduction zone / Continental crust (>25 km)   89.868228   44.542816
# 8     Subduction zone / Continental crust (>25 km)  313.616398  155.442671
# 9     Subduction zone / Continental crust (>25 km)  138.360176   68.577649
# 10    Subduction zone / Continental crust (>25 km)  368.696925  190.841800
# 11    Subduction zone / Continental crust (>25 km)  307.554905  301.219145
# 12    Subduction zone / Continental crust (>25 km)  131.508053   65.181422
# 13    Subduction zone / Continental crust (>25 km)  138.623719   68.708273
# 14    Subduction zone / Continental crust (>25 km)  203.455344  100.841800
# 15    Subduction zone / Continental crust (>25 km)   98.301611   48.722787
# 16    Subduction zone / Continental crust (>25 km)    0.000000    0.000000
# 17    Subduction zone / Continental crust (>25 km)  199.765739   99.013062
# 18    Subduction zone / Continental crust (>25 km)   86.178624   42.714078
# 19    Subduction zone / Continental crust (>25 km)   52.972182   26.255443
# 20    Subduction zone / Continental crust (>25 km)   37.686676   18.679245
# 21    Subduction zone / Continental crust (>25 km)  227.701318  311.538462
# 22    Subduction zone / Continental crust (>25 km)   76.163982   37.750363
# 23    Subduction zone / Continental crust (>25 km)  201.874085  258.505093
# 24    Subduction zone / Continental crust (>25 km)  368.696925  183.004354
# 25    Subduction zone / Continental crust (>25 km)  181.581259  310.362845
# 26    Subduction zone / Continental crust (>25 km)  108.843338   53.947750
# 27    Subduction zone / Continental crust (>25 km)   47.701318   23.642961
# 28    Subduction zone / Continental crust (>25 km)  368.696925  193.062409
# 29    Subduction zone / Continental crust (>25 km)    0.000000  323.555878
# ...                                            ...         ...         ...
# 3594  Subduction zone / Continental crust (>25 km)    0.000000  282.017417
# 3595  Subduction zone / Continental crust (>25 km)  339.443631  168.243832
# 3596  Subduction zone / Continental crust (>25 km)   53.235725  365.224951
# 3597  Subduction zone / Continental crust (>25 km)  188.960469   93.657475
# 3599  323.605485          237.84         190.560000
# 3600    0.000000           96.72         107.640000
# 3601  143.921094          226.32          23.160000
# 3602  329.898092          312.24         215.400012
# 3603  115.377538           17.04         368.880000
# 3604  324.019716          239.04         343.200000
# 3605  349.525483          222.72         356.519988
# 3606    1.972603          119.52           9.960000
# 3607    2.031781          122.88          11.520000
# 3608   51.544108          150.48         147.000000
# 3609  225.133145          300.24         203.160000
# 3610   62.787945          224.40          43.680000
# 3611  143.605485          314.40         104.160000
# 3612  213.356720          222.48         201.360012
# 3613   98.906299          137.28         152.760000
# 3614   98.275068           94.80         277.200000
# 3615    6.746301          181.68          34.680000
# 3616   50.222464          112.32         310.559988
# 3617   48.644384           88.08         115.680000
# 3618   75.964928          379.68         127.440000
# 3619  241.841092          173.28         167.640000
# 3620   54.384658          217.20         338.519988
# 3621  194.321100          280.56         208.920000
# 3622  143.447673          316.08         105.120000
# 3623  240.124937          176.64         358.080000
#
# [3624 rows x 43 columns]

# %% [markdown]
# import step -- done
#
#     import all modules
#
#     import all created modules
#
#     import two excel spreadsheets
#
# Prepare Data for Analysis
#
#     data wrangling step ---
#
#         get rid of uncertain dates (start dates) --- done
#
#         then perform a clean up of start and end dates --- done (could impute end dates)
#
#         convert dates to julian dates --- Done (start dates converted)
#
#         impute the VEI --- done
#
#         impute eruption length (to do) --- tonight by Sierra (12/3/2014)
#
#         merge eruptions and confirmed eruptions data frame --- done
#
#     Visualization Goal:
#         Output of DataFrame
#         plot the volcanoes on a map (with lat and long)
#         histogram on various features before and after data wrangling (to show changes if any)
#
#
#     F2PY --- done
#         import Fortran module --- done
#
#         calculate tidal forces for each eruption --- done
#
#         store data (via pickle) --- done
#
#         reload data --- done
#
#         merge dictionaries together --- done
#
#
# Determine Uniformity
#
# 	Perform Rayleigh Test
#
# 		Get phases of volcanic eruptions --- done
#
# 		plot these phases
#
# 		import Rayleigh module --- done
#
# 		comment on the uniformity of volcanic eruptions
#
#     Visualization Goal:
#         curves showing volcanic eruption rates
#         curves/histogram showing various tidal forces
#         comment on their period and characteristics
#         uniform probability plot
#
# Determine Correlation of Tidal Forces to Volcanic Data --- Sierra by 12/3/2014
# 	Derive and Explain Correlation model
#
# 	Describe parameters we will use
#
# 	Create correlation model
#
# 	Input Data and Determine Result
#
# 	comment on result and correlation between forces and volcanic eruptions
#
#     Visualization Goal:
#         Rose plot ( or linear histogram) --- Sierra by 12/3/2014?
#
#
#
# Feature Analysis: What types of volcanoes are most susceptible to these forces
#
# 	Create a decision tree
#
# 	Iterate through specific domain of features
#
# 	Determine the correlation between subset of volcanoes associated with those features
#
# 	Determine which features/domain of features are most predictive
#
# 	Visualization Goal:
# 		histograms
#
#
# Predictions
#
# 	Predict eruption rates based on volcanic features
#
# 	Visualization Goal:
# 		Plot showing linear boundaries and separation between the features

# %%
merged_tides07 = {k:v for d in (tides,tides7,tides8,tides9,tides10,tides11,tides12,tides13,tides14,tides15,tides16,tides17,tides18) for k, v in d.iteritems()}

# %%
len(merged_tides07)
# Out:
# 2624

# %%
tides = pickle.load(open('Tides/Tides/tides.txt', 'r'))

# %%
len(tides)
# Out:
# 200
